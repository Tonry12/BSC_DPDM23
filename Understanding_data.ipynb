# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/BSC_DPDM23/blob/main/Understanding_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Load data

# %% [markdown]
# ## Load Excel form Gdrive

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_1 = pd.read_excel('/content/drive/MyDrive/DPDM2023/2563.xls')

# %%
data_1
# Out:
#      Unnamed: 0          Unnamed: 1                               Unnamed: 2  \
# 0           NaN                 NaN                                      NaN
# 1    เลขที่คำขอ  เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย
# 2        610707    62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 3        620660    63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 4        610182    63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# ..          ...                 ...                                      ...
# 657     E630369    63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 658     E630401    63-0682-1-00-1-0                            โกลว์ พลังงาน
# 659     E630277    63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 660      610552    63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 661     E630269    63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _= default()

gc = gspread.authorize(creds)

# %%
gsht = gc.open_by_key('1j6LdobkfbYpY6_W94y-IwZ9q6NIGz9SRU2YvOi-35T4')

# %%
worksheet2 = gsht.worksheet('มิ.ย. 2563')
rows = worksheet2.get_all_values()
data_from_gsheets = pd.DataFrame.from_records(rows)

# %%
data_from_gsheets.colums = data_from_gsheets.iloc[2] #set header
data_from_gsheets = data_from_gsheets.iloc[2:].reset_index().iloc[:,1:] # skip rows
data_from_gsheets.head()
# Out:
# <ipython-input-14-f87b094cfd52>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data_from_gsheets.colums = data_from_gsheets.iloc[2] #set header
#           0                   1                                        2    \
# 0  เลขที่คำขอ  เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย
# 1      610707    62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 2      620660    63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 3      610182    63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# 4      620318    63-0080-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
#
#                                                  3              4    \
# 0                                  สถานที่ตั้งโรงงาน  เบอร์โทรศัพท์
# 1  46/1,46/2 หมู่ที่ 12 ถนนบางพลี-บางนาตราด ต.บาง...  02-3373078-84
# ...
