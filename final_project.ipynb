# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/BSC_DPDM23/blob/main/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
asso = pd.read_excel('/content/drive/MyDrive/DPDM2023/BSCproject/psdexercise.xlsx')

# %%
asso_act = asso[asso['กิจกรรม_2564'] !='-']

# %%
asso_act
# Out:
#          ปี      ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 3      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# 5      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 7      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   49
# ...     ...      ...          ...               ...         ...   ...  ...
# 20093  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# 20094  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   29
# 20095  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   40
# 20096  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   35
# 20097  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   35
#
#                                    การศึกษา     สถานภาพ  \
# 0                          มัธยมศึกษาตอนต้น  แยกกันอยู่
# 3               มัธยมศึกษาตอนปลาย สายสามัญ         สมรส
# 4                               ประถมศึกษา         สมรส
# 5                               ประถมศึกษา         หย่า
# 7                          มัธยมศึกษาตอนต้น       หม้าย
# ...                                     ...         ...
# 20093  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.        หย่า
# 20094  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.        สมรส
# 20095  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.        สมรส
# 20096                             ปริญญาตรี        สมรส
# 20097                             ปริญญาตรี        สมรส
#
#               การมีโรคประจำตัว  ...           นาที/วัน     วัน/สัปดาห์  \
# 0                        ไม่มี  ...              (1)45            (1)5
# 3                        ไม่มี  ...              (1)45            (1)3
# 4      เบาหวาน,ความดันโลหิตสูง  ...              (1)60            (1)3
# 5                      เบาหวาน  ...              (1)30            (1)3
# 7      เบาหวาน,ความดันโลหิตสูง  ...              (1)60            (1)7
# ...                        ...  ...                ...             ...
# 20093                    ไม่มี  ...        (1)40,(2)40       (1)4,(2)4
# 20094                    ไม่มี  ...        (1)40,(2)40       (1)3,(2)3
# 20095                    ไม่มี  ...  (1)50,(2)30,(3)40  (1)5,(2)2,(3)4
# 20096                    ไม่มี  ...              (1)30            (1)3
# 20097                    ไม่มี  ...              (1)40            (1)5
#
#            รวมสรุปกิจกรรม                                            สถานที่  \
# 0      (ระดับปานกลาง,225)  บ้าน/บริเวณที่พักอาศัย ,สวนสาธารณะ ,ถนน/ทางสาธ...
# 3      (ระดับปานกลาง,135)  บ้าน/บริเวณที่พักอาศัย ,ลานออกกำลังกาย/เล่นกีฬ...
# 4      (ระดับปานกลาง,180)                           ลานออกกำลังกาย/เล่นกีฬา
# 5       (ระดับปานกลาง,90)                            บ้าน/บริเวณที่พักอาศัย
# 7      (ระดับปานกลาง,420)                                          ที่ทำงาน
# ...                   ...                                                ...
# 20093  (ระดับปานกลาง,320)      บ้าน/บริเวณที่พักอาศัย ,ที่ทำงาน ,สวนสาธารณะ
# 20094  (ระดับปานกลาง,240)  ลานออกกำลังกาย/เล่นกีฬา ,สนามกีฬาประจำตำบล/อำเ...
# 20095  (ระดับปานกลาง,470)  บ้าน/บริเวณที่พักอาศัย ,ลานออกกำลังกาย/เล่นกีฬ...
# 20096   (ระดับปานกลาง,90)                บ้าน/บริเวณที่พักอาศัย ,สวนสาธารณะ
# 20097  (ระดับปานกลาง,200)                     ที่ทำงาน ,โรงเรียน/สถานศึกษา
#
#                                                     เวลา เวลารวม (ชั่วโมง)  \
# 0                  (06.00 - 07.00 น.),(18.00 - 19.00 น.)                 2
# 3                  (06.00 - 07.00 น.),(18.00 - 19.00 น.)                 2
# 4                  (07.00 - 08.00 น.),(18.00 - 19.00 น.)                 2
# 5                                     (16.00 - 17.00 น.)                 1
# 7                  (09.00 - 10.00 น.),(18.00 - 19.00 น.)                 2
# ...                                                  ...               ...
# 20093              (05.00 - 06.00 น.),(16.00 - 17.00 น.)                 2
# 20094              (05.00 - 06.00 น.),(16.00 - 17.00 น.)                 2
# 20095  (05.00 - 06.00 น.),(16.00 - 17.00 น.),(17.00 -...                 3
# 20096  (05.00 - 06.00 น.),(16.00 - 17.00 น.),(17.00 -...                 3
# 20097                                 (16.00 - 17.00 น.)                 1
#
#                                             เหตุผล (ออก) เหตุผล (ไม่ออก)  \
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...               -
# 3      ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก/ลดน้ำหน...               -
# 4      ต้องการให้ร่างกายแข็งแรง,รักษา/บรรเทาอาการเจ็บ...               -
# 5                                     คลายเครียด/พักผ่อน               -
# 7                                เป็นงานต้องทำ/เป็นอาชีพ               -
# ...                                                  ...             ...
# 20093                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน               -
# 20094                           ต้องการให้ร่างกายแข็งแรง               -
# 20095  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน,ใช้เวลาว่างให...               -
# 20096  ต้องการให้ร่างกายแข็งแรง,ทำกิจกรรมร่วมกับเพื่อ...               -
# 20097                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน               -
#
#                       แรงจูงใจ  \
# 0      ความรู้ในการออกกำลังกาย
# 3      ทัศนคติในการออกกำลังกาย
# 4          ผู้นำการออกกำลังกาย
# 5      ความรู้ในการออกกำลังกาย
# 7      ความรู้ในการออกกำลังกาย
# ...                        ...
# 20093       ญาติพี่น้อง/เพื่อน
# 20094  ความรู้ในการออกกำลังกาย
# 20095  การจัดกิจกรรมที่น่าสนใจ
# 20096       ญาติพี่น้อง/เพื่อน
# 20097  การจัดกิจกรรมที่น่าสนใจ
#
#                                               ข้อเสนอแนะ
# 0      ปรับปรุงซ่อมแซม สวนสาธารณะที่มีอยู่เดิมให้มีสภ...
# 3      ปรับปรุงซ่อมแซม สวนสาธารณะที่มีอยู่เดิมให้มีสภ...
# 4      สนับสนุนอุปกรณ์การกีฬา เครื่อง    ออกกำลังกายก...
# 5      ปรับปรุงซ่อมแซม สวนสาธารณะที่มีอยู่เดิมให้มีสภ...
# 7      ปรับปรุงซ่อมแซม สวนสาธารณะที่มีอยู่เดิมให้มีสภ...
# ...                                                  ...
# 20093                           สร้างสวนสาธารณะเพิ่มขึ้น
# 20094  ปรับปรุงซ่อมแซม สวนสาธารณะที่มีอยู่เดิมให้มีสภ...
# 20095  สนับสนุนอุปกรณ์การกีฬา เครื่อง    ออกกำลังกายก...
# 20096                           สร้างสวนสาธารณะเพิ่มขึ้น
# 20097                       อุปกรณ์การกีฬาควรมีราคาถูกลง
#
# [15501 rows x 26 columns]

# %%
asso_act_c = asso_act[['กิจกรรม_2564']]

# %%
asso_act_c
# Out:
#                             กิจกรรม_2564
# 0                         (1)ปั่นจักรยาน
# 3                                (1)วิ่ง
# 4                         (1)ปั่นจักรยาน
# 5                                (1)โยคะ
# 7      (1)การออกกำลังกายในการประกอบอาชีพ
# ...                                  ...
# 20093                    (1)เดิน,(2)วิ่ง
# 20094                  (1)เดิน,(2)ฟุตบอล
# 20095          (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096                            (1)เดิน
# 20097                      (1)วอลเลย์บอล
#
# [15501 rows x 1 columns]

# %%
asso_act_c_t = asso_act['กิจกรรม_2564'].str.split(',', expand=False)

# %%
asso_act_c_t
# Out:
# 0                           [(1)ปั่นจักรยาน]
# 3                                  [(1)วิ่ง]
# 4                           [(1)ปั่นจักรยาน]
# 5                                  [(1)โยคะ]
# 7        [(1)การออกกำลังกายในการประกอบอาชีพ]
#                         ...
# 20093                     [(1)เดิน, (2)วิ่ง]
# 20094                   [(1)เดิน, (2)ฟุตบอล]
# 20095          [(1)เดิน, (2)วิ่ง, (3)ฟุตบอล]
# 20096                              [(1)เดิน]
# 20097                        [(1)วอลเลย์บอล]
# Name: กิจกรรม_2564, Length: 15501, dtype: object

# %%
asso_act_c_t.apply(list)
# Out:
# 0                           [(1)ปั่นจักรยาน]
# 3                                  [(1)วิ่ง]
# 4                           [(1)ปั่นจักรยาน]
# 5                                  [(1)โยคะ]
# 7        [(1)การออกกำลังกายในการประกอบอาชีพ]
#                         ...
# 20093                     [(1)เดิน, (2)วิ่ง]
# 20094                   [(1)เดิน, (2)ฟุตบอล]
# 20095          [(1)เดิน, (2)วิ่ง, (3)ฟุตบอล]
# 20096                              [(1)เดิน]
# 20097                        [(1)วอลเลย์บอล]
# Name: กิจกรรม_2564, Length: 15501, dtype: object

# %%
import pandas as pd
import os
# !pip install apyori
from apyori import apriori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=b5f5c1ec9285126a7fd1fa25cc9f50051729f7f357ff5b99016e301f8a37477f
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
min_sup = 0.005
frequentItemsets = list(apriori(asso_act_c_t,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'(2)ปั่นจักรยาน', '(1)เดิน'}), support=0.007031804399716147, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'(2)ปั่นจักรยาน', '(1)เดิน'}), confidence=0.007031804399716147, lift=1.0), OrderedStatistic(items_base=frozenset({'(1)เดิน'}), items_add=frozenset({'(2)ปั่นจักรยาน'}), confidence=0.014397041341962753, lift=1.2680030559191173), OrderedStatistic(items_base=frozenset({'(2)ปั่นจักรยาน'}), items_add=frozenset({'(1)เดิน'}), confidence=0.6193181818181819, lift=1.2680030559191173)])
# yes
# RelationRecord(items=frozenset({'(2)วิ่ง', '(1)เดิน'}), support=0.024901619250370943, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'(2)วิ่ง', '(1)เดิน'}), confidence=0.024901619250370943, lift=1.0), OrderedStatistic(items_base=frozenset({'(1)เดิน'}), items_add=frozenset({'(2)วิ่ง'}), confidence=0.050984017963280934, lift=1.558783555125873), OrderedStatistic(items_base=frozenset({'(2)วิ่ง'}), items_add=frozenset({'(1)เดิน'}), confidence=0.7613412228796843, lift=1.5587835551258733)])

# %%
frequent_itemsets = list(apriori(asso_act_c_t, min_support = min_sup))

results = []

for itemset in frequent_itemsets:
    if len(itemset.items) > 1:
        item_info = {
            "yes": 'yes',
            "Items": ', '.join(itemset.items),
            "Support": f"{itemset.support:.4f} ({itemset.support*100:.2f}%)"
        }

        rules_info = []
        for rule_number, ordered_stat in enumerate(itemset.ordered_statistics, start=1):
            base_items = ', '.join(ordered_stat.items_base) if ordered_stat.items_base else 'None'
            add_items = ', '.join(ordered_stat.items_add)

            rules_info.append(f"Rule {rule_number}: ({base_items} -> {add_items} : Confidence={ordered_stat.confidence:.4f}, Lift={ordered_stat.lift:.4f})")

        item_info.update({"Rules": '\n'.join(rules_info)})
        results.append(item_info)
        results_df = pd.DataFrame(results)

results_df
# Out:
#    yes                    Items         Support  \
# 0  yes  (2)ปั่นจักรยาน, (1)เดิน  0.0070 (0.70%)
# 1  yes         (2)วิ่ง, (1)เดิน  0.0249 (2.49%)
#
#                                                Rules
# 0  Rule 1: (None -> (2)ปั่นจักรยาน, (1)เดิน : Con...
# 1  Rule 1: (None -> (2)วิ่ง, (1)เดิน : Confidence...

# %%
asso_act_h = asso[asso['เหตุผล (ออก)'] !='-']

# %%
asso_act_h_o = asso_act_h[['เหตุผล (ออก)']]
asso_act_h_o
# Out:
#                                             เหตุผล (ออก)
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# 3      ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก/ลดน้ำหน...
# 4      ต้องการให้ร่างกายแข็งแรง,รักษา/บรรเทาอาการเจ็บ...
# 5                                     คลายเครียด/พักผ่อน
# 7                                เป็นงานต้องทำ/เป็นอาชีพ
# ...                                                  ...
# 20093                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20094                           ต้องการให้ร่างกายแข็งแรง
# 20095  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน,ใช้เวลาว่างให...
# 20096  ต้องการให้ร่างกายแข็งแรง,ทำกิจกรรมร่วมกับเพื่อ...
# 20097                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
#
# [15501 rows x 1 columns]

# %%
asso_act_h_o_t = asso_act_h_o['เหตุผล (ออก)'].str.split('/', expand=False)

# %%
asslist = asso_act_h_o_t.apply(list)

# %%
asslist
# Out:
# 0        [ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี,...
# 3        [ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก, ลดน้ำ...
# 4        [ต้องการให้ร่างกายแข็งแรง,รักษา, บรรเทาอาการเจ...
# 5                                    [คลายเครียด, พักผ่อน]
# 7                               [เป็นงานต้องทำ, เป็นอาชีพ]
#                                ...
# 20093                  [ทำกิจกรรมร่วมกับเพื่อน, เพื่อนชวน]
# 20094                           [ต้องการให้ร่างกายแข็งแรง]
# 20095    [ทำกิจกรรมร่วมกับเพื่อน, เพื่อนชวน,ใช้เวลาว่าง...
# 20096    [ต้องการให้ร่างกายแข็งแรง,ทำกิจกรรมร่วมกับเพื่...
# 20097                  [ทำกิจกรรมร่วมกับเพื่อน, เพื่อนชวน]
# Name: เหตุผล (ออก), Length: 15501, dtype: object

# %%
min_sup = 0.025
frequentItemsets = list(apriori(asslist,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'พักผ่อน', 'ต้องการให้ร่างกายแข็งแรง,คลายเครียด'}), support=0.03257854331978582, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'พักผ่อน', 'ต้องการให้ร่างกายแข็งแรง,คลายเครียด'}), confidence=0.03257854331978582, lift=1.0), OrderedStatistic(items_base=frozenset({'ต้องการให้ร่างกายแข็งแรง,คลายเครียด'}), items_add=frozenset({'พักผ่อน'}), confidence=0.8145161290322579, lift=5.677074872360175), OrderedStatistic(items_base=frozenset({'พักผ่อน'}), items_add=frozenset({'ต้องการให้ร่างกายแข็งแรง,คลายเครียด'}), confidence=0.22706834532374098, lift=5.677074872360175)])
# yes
# RelationRecord(items=frozenset({'เป็นอาชีพ', 'ต้องการให้ร่างกายแข็งแรง,เป็นงานต้องทำ'}), support=0.02503064318431069, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'เป็นอาชีพ', 'ต้องการให้ร่างกายแข็งแรง,เป็นงานต้องทำ'}), confidence=0.02503064318431069, lift=1.0), OrderedStatistic(items_base=frozenset({'ต้องการให้ร่างกายแข็งแรง,เป็นงานต้องทำ'}), items_add=frozenset({'เป็นอาชีพ'}), confidence=0.5132275132275133, lift=8.011621029747918), OrderedStatistic(items_base=frozenset({'เป็นอาชีพ'}), items_add=frozenset({'ต้องการให้ร่างกายแข็งแรง,เป็นงานต้องทำ'}), confidence=0.3907351460221551, lift=8.011621029747918)])
# yes
# RelationRecord(items=frozenset({'พักผ่อน', 'ลดน้ำหนัก,คลายเครียด'}), support=0.026836978259467133, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'พักผ่อน', 'ลดน้ำหนัก,คลายเครียด'}), confidence=0.026836978259467133, lift=1.0), OrderedStatistic(items_base=frozenset({'พักผ่อน'}), items_add=frozenset({'ลดน้ำหนัก,คลายเครียด'}), confidence=0.18705035971223022, lift=4.189982118351562), OrderedStatistic(items_base=frozenset({'ลดน้ำหนัก,คลายเครียด'}), items_add=frozenset({'พักผ่อน'}), confidence=0.6011560693641619, lift=4.189982118351562)])
# yes
# RelationRecord(items=frozenset({'เป็นงานต้องทำ', 'เป็นอาชีพ'}), support=0.03902974001677311, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'เป็นงานต้องทำ', 'เป็นอาชีพ'}), confidence=0.03902974001677311, lift=1.0), OrderedStatistic(items_base=frozenset({'เป็นงานต้องทำ'}), items_add=frozenset({'เป็นอาชีพ'}), confidence=0.7867360208062419, lift=12.281163200924025), OrderedStatistic(items_base=frozenset({'เป็นอาชีพ'}), items_add=frozenset({'เป็นงานต้องทำ'}), confidence=0.6092648539778449, lift=12.281163200924023)])

# %%
frequent_itemsets = list(apriori(asslist, min_support = min_sup))

results = []

for itemset in frequent_itemsets:
    if len(itemset.items) > 1:
        item_info = {
            "yes": 'yes',
            "Items": ', '.join(itemset.items),
            "Support": f"{itemset.support:.4f} ({itemset.support*100:.2f}%)"
        }

        rules_info = []
        for rule_number, ordered_stat in enumerate(itemset.ordered_statistics, start=1):
            base_items = ', '.join(ordered_stat.items_base) if ordered_stat.items_base else 'None'
            add_items = ', '.join(ordered_stat.items_add)

            rules_info.append(f"Rule {rule_number}: ({base_items} -> {add_items} : Confidence={ordered_stat.confidence:.4f}, Lift={ordered_stat.lift:.4f})")

        item_info.update({"Rules": '\n'.join(rules_info)})
        results.append(item_info)
        results_df = pd.DataFrame(results)

results_df
# Out:
#    yes                                              Items         Support  \
# 0  yes       พักผ่อน, ต้องการให้ร่างกายแข็งแรง,คลายเครียด  0.0326 (3.26%)
# 1  yes  เป็นอาชีพ, ต้องการให้ร่างกายแข็งแรง,เป็นงานต้องทำ  0.0250 (2.50%)
# 2  yes                      พักผ่อน, ลดน้ำหนัก,คลายเครียด  0.0268 (2.68%)
# 3  yes                           เป็นงานต้องทำ, เป็นอาชีพ  0.0390 (3.90%)
#
#                                                Rules
# 0  Rule 1: (None -> พักผ่อน, ต้องการให้ร่างกายแข็...
# 1  Rule 1: (None -> เป็นอาชีพ, ต้องการให้ร่างกายแ...
# 2  Rule 1: (None -> พักผ่อน, ลดน้ำหนัก,คลายเครียด...
# 3  Rule 1: (None -> เป็นงานต้องทำ, เป็นอาชีพ : Co...

# %% [markdown]
# # Prep

# %%
asso.columns
# Out:
# Index(['ปี', 'ภาค', 'จังหวัด', 'อำเภอ', 'ตำบล', 'เพศ', 'อายุ', 'การศึกษา',
#        'สถานภาพ', 'การมีโรคประจำตัว', 'ประเภทของโรค', 'อาชีพ', 'น้ำหนัก',
#        'ส่วนสูง', 'กิจกรรม_2564', 'ระดับ', 'นาที/วัน', 'วัน/สัปดาห์',
#        'รวมสรุปกิจกรรม', 'สถานที่', 'เวลา', 'เวลารวม (ชั่วโมง)',
#        'เหตุผล (ออก)', 'เหตุผล (ไม่ออก)', 'แรงจูงใจ', 'ข้อเสนอแนะ'],
#       dtype='object')

# %%
df = asso[['ปี','ภาค','เพศ','อายุ', 'การศึกษา',
       'สถานภาพ', 'การมีโรคประจำตัว','อาชีพ','กิจกรรม_2564','รวมสรุปกิจกรรม','เหตุผล (ออก)']]

# %%
df
# Out:
#          ปี      ภาค   เพศ อายุ                              การศึกษา  \
# 0      2564  ภาคกลาง  หญิง   55                      มัธยมศึกษาตอนต้น
# 1      2564  ภาคกลาง  หญิง   47           มัธยมศึกษาตอนปลาย สายอาชีพ
# 2      2564  ภาคกลาง   ชาย   45                             ปริญญาตรี
# 3      2564  ภาคกลาง   ชาย   53           มัธยมศึกษาตอนปลาย สายสามัญ
# 4      2564  ภาคกลาง   ชาย   57                           ประถมศึกษา
# ...     ...      ...   ...  ...                                   ...
# 20093  2565   ภาคใต้  หญิง   48  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.
# 20094  2565   ภาคใต้   ชาย   29  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.
# 20095  2565   ภาคใต้   ชาย   40  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.
# 20096  2565   ภาคใต้   ชาย   35                             ปริญญาตรี
# 20097  2565   ภาคใต้  หญิง   35                             ปริญญาตรี
#
#           สถานภาพ         การมีโรคประจำตัว                        อาชีพ  \
# 0      แยกกันอยู่                    ไม่มี                รับจ้างทั่วไป
# 1            สมรส                    ไม่มี          ประกอบธุรกิจส่วนตัว
# 2            สมรส                    ไม่มี                รับจ้างทั่วไป
# 3            สมรส                    ไม่มี       พนักงานบริษัท/ห้างร้าน
# 4            สมรส  เบาหวาน,ความดันโลหิตสูง  รับราชการ/เจ้าหน้าที่ของรัฐ
# ...           ...                      ...                          ...
# 20093        หย่า                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
# 20094        สมรส                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
# 20095        สมรส                    ไม่มี                       ค้าขาย
# 20096        สมรส                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
# 20097        สมรส                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
#
#                     กิจกรรม_2564      รวมสรุปกิจกรรม  \
# 0                 (1)ปั่นจักรยาน  (ระดับปานกลาง,225)
# 1                              -                   -
# 2                              -                   -
# 3                        (1)วิ่ง  (ระดับปานกลาง,135)
# 4                 (1)ปั่นจักรยาน  (ระดับปานกลาง,180)
# ...                          ...                 ...
# 20093            (1)เดิน,(2)วิ่ง  (ระดับปานกลาง,320)
# 20094          (1)เดิน,(2)ฟุตบอล  (ระดับปานกลาง,240)
# 20095  (1)เดิน,(2)วิ่ง,(3)ฟุตบอล  (ระดับปานกลาง,470)
# 20096                    (1)เดิน   (ระดับปานกลาง,90)
# 20097              (1)วอลเลย์บอล  (ระดับปานกลาง,200)
#
#                                             เหตุผล (ออก)
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# 1                                                      -
# 2                                                      -
# 3      ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก/ลดน้ำหน...
# 4      ต้องการให้ร่างกายแข็งแรง,รักษา/บรรเทาอาการเจ็บ...
# ...                                                  ...
# 20093                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20094                           ต้องการให้ร่างกายแข็งแรง
# 20095  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน,ใช้เวลาว่างให...
# 20096  ต้องการให้ร่างกายแข็งแรง,ทำกิจกรรมร่วมกับเพื่อ...
# 20097                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
#
# [20098 rows x 11 columns]

# %%
classification = df[['ปี','ภาค','เพศ','อายุ', 'การศึกษา',
       'สถานภาพ', 'การมีโรคประจำตัว','อาชีพ','รวมสรุปกิจกรรม']]

# %%
classification
# Out:
#          ปี      ภาค   เพศ อายุ                              การศึกษา  \
# 0      2564  ภาคกลาง  หญิง   55                      มัธยมศึกษาตอนต้น
# 1      2564  ภาคกลาง  หญิง   47           มัธยมศึกษาตอนปลาย สายอาชีพ
# 2      2564  ภาคกลาง   ชาย   45                             ปริญญาตรี
# 3      2564  ภาคกลาง   ชาย   53           มัธยมศึกษาตอนปลาย สายสามัญ
# 4      2564  ภาคกลาง   ชาย   57                           ประถมศึกษา
# ...     ...      ...   ...  ...                                   ...
# 20093  2565   ภาคใต้  หญิง   48  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.
# 20094  2565   ภาคใต้   ชาย   29  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.
# 20095  2565   ภาคใต้   ชาย   40  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.
# 20096  2565   ภาคใต้   ชาย   35                             ปริญญาตรี
# 20097  2565   ภาคใต้  หญิง   35                             ปริญญาตรี
#
#           สถานภาพ         การมีโรคประจำตัว                        อาชีพ  \
# 0      แยกกันอยู่                    ไม่มี                รับจ้างทั่วไป
# 1            สมรส                    ไม่มี          ประกอบธุรกิจส่วนตัว
# 2            สมรส                    ไม่มี                รับจ้างทั่วไป
# 3            สมรส                    ไม่มี       พนักงานบริษัท/ห้างร้าน
# 4            สมรส  เบาหวาน,ความดันโลหิตสูง  รับราชการ/เจ้าหน้าที่ของรัฐ
# ...           ...                      ...                          ...
# 20093        หย่า                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
# 20094        สมรส                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
# 20095        สมรส                    ไม่มี                       ค้าขาย
# 20096        สมรส                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
# 20097        สมรส                    ไม่มี  รับราชการ/เจ้าหน้าที่ของรัฐ
#
#            รวมสรุปกิจกรรม
# 0      (ระดับปานกลาง,225)
# 1                       -
# 2                       -
# 3      (ระดับปานกลาง,135)
# 4      (ระดับปานกลาง,180)
# ...                   ...
# 20093  (ระดับปานกลาง,320)
# 20094  (ระดับปานกลาง,240)
# 20095  (ระดับปานกลาง,470)
# 20096   (ระดับปานกลาง,90)
# 20097  (ระดับปานกลาง,200)
#
# [20098 rows x 9 columns]

# %%
associate = df[['กิจกรรม_2564','เหตุผล (ออก)']]

# %%
association = associate[associate['เหตุผล (ออก)'] !='-']
association
# Out:
#                             กิจกรรม_2564  \
# 0                         (1)ปั่นจักรยาน
# 3                                (1)วิ่ง
# 4                         (1)ปั่นจักรยาน
# 5                                (1)โยคะ
# 7      (1)การออกกำลังกายในการประกอบอาชีพ
# ...                                  ...
# 20093                    (1)เดิน,(2)วิ่ง
# 20094                  (1)เดิน,(2)ฟุตบอล
# 20095          (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096                            (1)เดิน
# 20097                      (1)วอลเลย์บอล
#
#                                             เหตุผล (ออก)
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# 3      ต้องการให้ร่างกายแข็งแรง,ควบคุมน้ำหนัก/ลดน้ำหน...
# 4      ต้องการให้ร่างกายแข็งแรง,รักษา/บรรเทาอาการเจ็บ...
# 5                                     คลายเครียด/พักผ่อน
# 7                                เป็นงานต้องทำ/เป็นอาชีพ
# ...                                                  ...
# 20093                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20094                           ต้องการให้ร่างกายแข็งแรง
# 20095  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน,ใช้เวลาว่างให...
# 20096  ต้องการให้ร่างกายแข็งแรง,ทำกิจกรรมร่วมกับเพื่อ...
# 20097                   ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
#
# [15501 rows x 2 columns]

# %% [markdown]
# ## Prep ข้อมูล class

# %%
classification[classification['การมีโรคประจำตัว'] !='ไม่มี']
# Out:
#          ปี      ภาค   เพศ อายุ                              การศึกษา สถานภาพ  \
# 4      2564  ภาคกลาง   ชาย   57                           ประถมศึกษา     สมรส
# 5      2564  ภาคกลาง  หญิง   55                           ประถมศึกษา     หย่า
# 7      2564  ภาคกลาง   ชาย   49                      มัธยมศึกษาตอนต้น   หม้าย
# 12     2564  ภาคกลาง   ชาย   72                           ประถมศึกษา     สมรส
# 14     2564  ภาคกลาง   ชาย   63                           ประถมศึกษา     สมรส
# ...     ...      ...   ...  ...                                   ...     ...
# 20075  2565   ภาคใต้   ชาย   55                           ประถมศึกษา     สมรส
# 20080  2565   ภาคใต้  หญิง   60                           ประถมศึกษา     สมรส
# 20084  2565   ภาคใต้  หญิง   59                      มัธยมศึกษาตอนต้น    สมรส
# 20087  2565   ภาคใต้   ชาย   54                             ปริญญาตรี    สมรส
# 20089  2565   ภาคใต้   ชาย   17  มัธยมศึกษาตอนปลาย สายอาชีพ เช่น ปวช.     โสด
#
#                                         การมีโรคประจำตัว  \
# 4                                เบาหวาน,ความดันโลหิตสูง
# 5                                                เบาหวาน
# 7                                เบาหวาน,ความดันโลหิตสูง
# 12     มะเร็งอื่น ๆ,ความดันโลหิตสูง,โรคหัวใจ (หัวใจโต...
# 14                                               เบาหวาน
# ...                                                  ...
# 20075                                           โรคหัวใจ
# 20080                                             เก๊าท์
# 20084                                    ความดันโลหิตสูง
# 20087                            เบาหวาน,ความดันโลหิตสูง
# 20089                                            ภูมิแพ้
#
#                                     อาชีพ      รวมสรุปกิจกรรม
# 4             รับราชการ/เจ้าหน้าที่ของรัฐ  (ระดับปานกลาง,180)
# 5                           รับจ้างทั่วไป   (ระดับปานกลาง,90)
# 7                     ประกอบธุรกิจส่วนตัว  (ระดับปานกลาง,420)
# 12     ชรา/ป่วย/พิการ จนไม่สามารถทำงานได้  (ระดับปานกลาง,105)
# 14                 พนักงานบริษัท/ห้างร้าน                   -
# ...                                   ...                 ...
# 20075                       รับจ้างทั่วไป   (ระดับปานกลาง,70)
# 20080                              ค้าขาย   (ระดับปานกลาง,30)
# 20084                       รับจ้างทั่วไป  (ระดับปานกลาง,210)
# 20087         รับราชการ/เจ้าหน้าที่ของรัฐ  (ระดับปานกลาง,255)
# 20089                   นักเรียน/นักศึกษา     (ระดับหนัก,420)
#
# [4669 rows x 9 columns]
